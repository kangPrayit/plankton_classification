# %%
import os
from utils import *

# %%
data_dir = '../datasets/plankton_cocov2'
train_dir = data_dir + '/train/'
test_dir = data_dir + '/test/'
valid_dir = data_dir + '/valid'

# %%
os.listdir(data_dir)
# Out:
# ['README.dataset.txt', 'README.roboflow.txt', 'test', 'train', 'valid']

# %%
import json
train_anotation_json = "../datasets/plankton_cocov2/train/_annotations.coco.json"
f = open(train_anotation_json)
annotations = json.load(f)
print(annotations.keys())
# Out:
# dict_keys(['info', 'licenses', 'categories', 'images', 'annotations'])

# %%
annotations['info']
# Out:
# {'year': '2023',
#  'version': '1',
#  'description': 'Exported from roboflow.ai',
#  'contributor': '',
#  'url': 'https://public.roboflow.ai/object-detection/undefined',
#  'date_created': '2023-05-16T09:40:09+00:00'}

# %%
annotations['licenses']
# Out:
# [{'id': 1,
#   'url': 'https://creativecommons.org/licenses/by/4.0/',
#   'name': 'CC BY 4.0'}]

# %%
annotations['categories']
# Out:
# [{'id': 0, 'name': 'planktons', 'supercategory': 'none'},
#  {'id': 1, 'name': 'asteromphalus_hyalinus', 'supercategory': 'planktons'},
#  {'id': 2, 'name': 'ceratium_furca', 'supercategory': 'planktons'},
#  {'id': 3, 'name': 'ceratium_trichorecos', 'supercategory': 'planktons'},
#  {'id': 4, 'name': 'chaetoceros_curvisetus', 'supercategory': 'planktons'},
#  {'id': 5,
#   'name': 'coscinodiscus_oculus_iridis',
#   'supercategory': 'planktons'},
#  {'id': 6, 'name': 'dinophysis_caudata', 'supercategory': 'planktons'},
#  {'id': 7, 'name': 'dinophysis_miles', 'supercategory': 'planktons'},
#  {'id': 8, 'name': 'eucampia_zodiacus', 'supercategory': 'planktons'},
#  {'id': 9, 'name': 'noctilluca_scintillans', 'supercategory': 'planktons'},
#  {'id': 10, 'name': 'odontella_mobiliensis', 'supercategory': 'planktons'},
#  {'id': 11, 'name': 'ornithocercus_thumii', 'supercategory': 'planktons'},
#  {'id': 12, 'name': 'planktoniella_sol', 'supercategory': 'planktons'},
#  {'id': 13, 'name': 'podolampas_bipes', 'supercategory': 'planktons'},
#  {'id': 14, 'name': 'proboscia_alata', 'supercategory': 'planktons'},
#  {'id': 15, 'name': 'prorocentrum_micans', 'supercategory': 'planktons'},
#  {'id': 16, 'name': 'protoperidinium_oceanicum', 'supercategory': 'planktons'},
#  {'id': 17, 'name': 'pseudo_nitzschia', 'supercategory': 'planktons'},
#  {'id': 18, 'name': 'skeletonema_costatum', 'supercategory': 'planktons'},
#  {'id': 19,
#   'name': 'thalassionema_nitzschioides',
#   'supercategory': 'planktons'},
#  {'id': 20, 'name': 'trichodesmium_erythraeum', 'supercategory': 'planktons'}]

# %%
annotations['images']
# Out:
# [{'id': 0,
#   'license': 1,
#   'file_name': '16_pseudo_nitzschia_JPG.rf.fa679d96aea22eaffeabcd3f808752c4.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 1,
#   'license': 1,
#   'file_name': '01_podolampas_bipes_jpg.rf.f963bed7a9540d5767c7e868fc7c91fa.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 2,
#   'license': 1,
#   'file_name': '09_proboscia_alata_jpg.rf.fb92de86683f993bd9fd38c210c7ee97.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 3,
#   'license': 1,
#   'file_name': '18_proboscia_alata_jpg.rf.fe63547bc8ecdac9f77b8d2719daed1d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 4,
#   'license': 1,
#   'file_name': '20_protoperidinium_oceanicum_jpg.rf.f9f7deaf016303b695190c9616923504.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 5,
#   'license': 1,
#   'file_name': '10_ornithocercus_thumii_jpg.rf.fd9ed4fdf788ba2e1104f70d7d42c6f1.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 6,
#   'license': 1,
#   'file_name': '23_ornithocercus_thumii_jpg.rf.ff6f86daf710e69817c7b365a72f395e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 7,
#   'license': 1,
#   'file_name': '01_skeletonema_costatum_jpg.rf.feecfcb37255f97f95ab0cb13664f342.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 8,
#   'license': 1,
#   'file_name': '05_chaetoceros_curvisetus_jpg.rf.ffeb57da4fbef016caf49d83c36987de.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 9,
#   'license': 1,
#   'file_name': '09_pseudo_nitzschia_JPG.rf.00adf54109f25846e538e964242203b8.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 10,
#   'license': 1,
#   'file_name': '11_ceratium_furca_jpg.rf.0c04b679ae25f62c5f061d618030fcc7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 11,
#   'license': 1,
#   'file_name': '13_pseudo_nitzschia_JPG.rf.0145297bd7ae941f3b798a2776323d1d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 12,
#   'license': 1,
#   'file_name': '02_skeletonema_costatum_jpg.rf.07aec65735bba85e9e6281cf9fb19aa5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 13,
#   'license': 1,
#   'file_name': '04_chaetoceros_curvisetus_jpg.rf.1016e13d8c3bc3cf4b2f9ffb17fdc942.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 14,
#   'license': 1,
#   'file_name': '01_pseudo_nitzschia_jpg.rf.0660090bd4c1ab2c27096d564074fb35.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 15,
#   'license': 1,
#   'file_name': '14_ornithocercus_thumii_jpg.rf.0a1eeb248e3ec61b95344503dc8baeca.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 16,
#   'license': 1,
#   'file_name': '27_coscinodiscus_oculus_iridis_jpg.rf.0e9f7341ab3a2243bc96201b7b7ef984.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 17,
#   'license': 1,
#   'file_name': '02_asteromphalus_hyalinus_jpg.rf.135dcdc46ed9013c35a3b624a8310e31.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 18,
#   'license': 1,
#   'file_name': '01_asteromphalus_hyalinus_jpg.rf.09d3a664a15c5c703d79e9f4d8d98b16.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 19,
#   'license': 1,
#   'file_name': '08_odontella_mobiliensis_jpg.rf.106411ba8e27e62ba869e527c69dfc55.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 20,
#   'license': 1,
#   'file_name': '32_pseudo_nitzschia_JPG.rf.0be11a8f8b49736a4deca148574fe840.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 21,
#   'license': 1,
#   'file_name': '08_planktoniella_sol_jpg.rf.1242f38e69b76fba43558c0410235608.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 22,
#   'license': 1,
#   'file_name': '09_podolampas_bipes_jpg.rf.134e43048c8f9851ae248b76aae91aa7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 23,
#   'license': 1,
#   'file_name': '11_podolampas_bipes_jpg.rf.032275ce078e6e16b2bd28c9a8713ca5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 24,
#   'license': 1,
#   'file_name': '13_ornithocercus_thumii_jpg.rf.1066eabc38e89c5bb5ac786f5c720cd2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 25,
#   'license': 1,
#   'file_name': '05_odontella_mobiliensis_jpg.rf.04465c1a62d4e11d6803bc81a2cae334.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 26,
#   'license': 1,
#   'file_name': '07_chaetoceros_curvisetus_jpg.rf.01e65eb6f2b29513956a45a1ccc3abb2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 27,
#   'license': 1,
#   'file_name': '06_podolampas_bipes_jpg.rf.1b9b7108f504676e657d32607a64073f.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 28,
#   'license': 1,
#   'file_name': '05_proboscia_alata_jpg.rf.1b79adeb9d35e6fce2eea274fec0c884.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 29,
#   'license': 1,
#   'file_name': '25_thalassionema_nitzschioides_jpg.rf.1bd220eb408402304f58f20b884af299.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 30,
#   'license': 1,
#   'file_name': '01_dinophysis_caudata_jpg.rf.1e29c6b4f4b3f77ba457b1b43057ea79.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 31,
#   'license': 1,
#   'file_name': '25_asteromphalus_hyalinus_jpg.rf.1eacfa14ef4fcc037cc3369a820d7b1b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 32,
#   'license': 1,
#   'file_name': '05_pseudo_nitzschia_jpg.rf.189d332507b0d667c529024dedea841a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 33,
#   'license': 1,
#   'file_name': '02_ceratium_trichoceros_jpg.rf.1f5e6918ba99e9f58cd34013b6d5bb26.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 34,
#   'license': 1,
#   'file_name': '09_asteromphalus_hyalinus_jpg.rf.1e49690e40782aa865a8ff5d177970ab.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 35,
#   'license': 1,
#   'file_name': '04_protoperidinium_oceanicum_jpg.rf.1e0412d382a394548673e4ac56c2bf48.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 36,
#   'license': 1,
#   'file_name': '02_chaetoceros_curvisetus_jpg.rf.1f428fbe207d733d702d3a053f8d865d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 37,
#   'license': 1,
#   'file_name': '24_pseudo_nitzschia_jpg.rf.20a9727feca2acd791369398a1593466.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 38,
#   'license': 1,
#   'file_name': '04_coscinodiscus_oculus_iridis_jpg.rf.1aefa36e4543cbdf2d22a0a65ad36bc6.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 39,
#   'license': 1,
#   'file_name': '19_coscinodiscus_oculus_iridis_jpg.rf.2537b9edd169091210e57a851eacb8f4.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 40,
#   'license': 1,
#   'file_name': '13_protoperidinium_oceanicum_jpg.rf.20fe55fd84f9dd84d6de78cdfe3ee7c9.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 41,
#   'license': 1,
#   'file_name': '16_proboscia_alata_jpg.rf.16ae38717f770440aea44ebc5d4b72d5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 42,
#   'license': 1,
#   'file_name': '12_pseudo_nitzschia_JPG.rf.2751ca55a07a2ded7fd677c74bbc9daf.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 43,
#   'license': 1,
#   'file_name': '15_coscinodiscus_oculus_iridis_jpg.rf.2843f07f17c1e1f0253a7c7b99b7332a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 44,
#   'license': 1,
#   'file_name': '10_coscinodiscus_oculus_iridis_jpg.rf.2446a1356bc5ff62b85549d2d8563426.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 45,
#   'license': 1,
#   'file_name': '06_pseudo_nitzschia_JPG.rf.2ec78dfe3823633c1fcb9fa815f6841a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 46,
#   'license': 1,
#   'file_name': '03_prorocentrum_micans_jpg.rf.23f5c79a340c519964dd1e4676679c97.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 47,
#   'license': 1,
#   'file_name': '20_ornithocercus_thumii_jpg.rf.290fa9e511459ef378fe626c6eccf264.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 48,
#   'license': 1,
#   'file_name': '08_ceratium_trichoceros_jpg.rf.29d63e0c2381392a4f814b3c54898879.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 49,
#   'license': 1,
#   'file_name': '03_podolampas_bipes_jpg.rf.1f26a7276485ae88124747ea5a469047.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 50,
#   'license': 1,
#   'file_name': '07_trichodesmium_erythraeum_jpg.rf.2dda19daf06b30f1c4de3bf9375767fc.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 51,
#   'license': 1,
#   'file_name': '13_dinophysis_miles_jpg.rf.20e28fc0236bf4844bad99cb2ddad9b6.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 52,
#   'license': 1,
#   'file_name': '11_asteromphalus_hyalinus_jpg.rf.301763ed3e0eba09295e838b290e9a8d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 53,
#   'license': 1,
#   'file_name': '29_ornithocercus_thumii_jpg.rf.2ecbbde49b79ada6e81571aade3433b5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 54,
#   'license': 1,
#   'file_name': '05_eucampia_zodiacus_jpg.rf.2f69138c261c89f268ee040cb11ec953.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 55,
#   'license': 1,
#   'file_name': '09_ornithocercus_thumii_jpg.rf.1f4f86ce04a895a931f17b7bfae441d9.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 56,
#   'license': 1,
#   'file_name': '05_ceratium_furca_jpg.rf.307b48c04aac9b0b839fc3aab7bd8ddc.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 57,
#   'license': 1,
#   'file_name': '30_thalassionema_nitzschioides_jpg.rf.213e6a27a6aca563cc772a306fc6e336.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 58,
#   'license': 1,
#   'file_name': '18_coscinodiscus_oculus_iridis_jpg.rf.21f8f52139c1522d09433040aff37c3a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 59,
#   'license': 1,
#   'file_name': '14_dinophysis_miles_jpg.rf.355c4823a23f1aec5b8ab72f9ef3057a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 60,
#   'license': 1,
#   'file_name': '10_odontella_mobiliensis_jpg.rf.3578778d30238bac46e0349f9c42988f.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 61,
#   'license': 1,
#   'file_name': '13_dinophysis_caudata_jpg.rf.295cabcbe5b1e958e45d6ee40d9ed982.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 62,
#   'license': 1,
#   'file_name': '02_coscinodiscus_oculus_iridis_jpg.rf.1fe1a89e46c89ba20d96e3325e0bd901.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 63,
#   'license': 1,
#   'file_name': '06_ceratium_furca_jpg.rf.3580e19d87d938b2bbe908cb4c8bdc45.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 64,
#   'license': 1,
#   'file_name': '27_pseudo_nitzschia_jpg.rf.1fd633b5c48c569ae45e61aa23ad9189.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 65,
#   'license': 1,
#   'file_name': '03_proboscia_alata_jpg.rf.3440ea8d328ccd3062e68d23eb28e62e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 66,
#   'license': 1,
#   'file_name': '10_prorocentrum_micans_jpg.rf.35d9fc41fec0bf4aea2389c14cc12847.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 67,
#   'license': 1,
#   'file_name': '15_proboscia_alata_jpg.rf.48d59a6fb04933e171125bbec0ada581.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 68,
#   'license': 1,
#   'file_name': '14_eucampia_zodiacus_jpg.rf.3b770ab5ef9b519c3b44b6def17ed30b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 69,
#   'license': 1,
#   'file_name': '12_dinophysis_miles_jpg.rf.3c8575cfa2be1b954958e507a62b1e0b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 70,
#   'license': 1,
#   'file_name': '02_planktoniella_sol_jpg.rf.3b35cd5fbed09ebe2bf2c4603c584c73.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 71,
#   'license': 1,
#   'file_name': '12_asteromphalus_hyalinus_jpg.rf.4a57de67a82f5bf4ddd6b94f34201cff.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 72,
#   'license': 1,
#   'file_name': '09_ceratium_furca_jpg.rf.3c45b338127901329b24d7d53965f0f8.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 73,
#   'license': 1,
#   'file_name': '07_odontella_mobiliensis_jpg.rf.45d3b8d25c784d875228d065ce22b75d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 74,
#   'license': 1,
#   'file_name': '01_trichodesmium_erythraeum_jpg.rf.38c63aa9cb859fe02e9df4c1f320beb2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 75,
#   'license': 1,
#   'file_name': '17_ornithocercus_thumii_jpg.rf.4ab16bc1b9afade130cbade47359f451.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 76,
#   'license': 1,
#   'file_name': '02_odontella_mobiliensis_jpg.rf.4cb11b1cfabed1d74666efe65c682e9c.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 77,
#   'license': 1,
#   'file_name': '02_dinophysis_caudata_jpg.rf.4aa075874e1a769158ebd06b3579569e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 78,
#   'license': 1,
#   'file_name': '11_pseudo_nitzschia_JPG.rf.42e2aa374d60e515adc892b29e8afe29.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 79,
#   'license': 1,
#   'file_name': '21_coscinodiscus_oculus_iridis_jpg.rf.35441db4d343a9a173eff0fb3fc3cdbf.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 80,
#   'license': 1,
#   'file_name': '06_dinophysis_caudata_jpg.rf.47c99095c4dd31b8e4edfa186ee477cc.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 81,
#   'license': 1,
#   'file_name': '03_ceratium_furca_jpg.rf.4f9b89c96395ce3b7d47b06e7f4f1ac1.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 82,
#   'license': 1,
#   'file_name': '11_proboscia_alata_jpg.rf.4f531231945ad8c12f08c968c6bfcb06.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 83,
#   'license': 1,
#   'file_name': '30_asteromphalus_hyalinus_jpg.rf.4ca4fd64ab91e8b86f45756da9f1ef3a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 84,
#   'license': 1,
#   'file_name': '11_ceratium_trichoceros_jpg.rf.5831f57b7cf2ab92b1b141917b1668f2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 85,
#   'license': 1,
#   'file_name': '04_ornithocercus_thumii_jpg.rf.4f2aab4afbcd6a8e18d3cdb543c852f3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 86,
#   'license': 1,
#   'file_name': '01_eucampia_zodiacus_jpg.rf.3d3bf80bd4fd971b1f6a34503c5e058e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 87,
#   'license': 1,
#   'file_name': '12_protoperidinium_oceanicum_jpg.rf.4fb0ceaacb87038db34a8fbcd594492d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 88,
#   'license': 1,
#   'file_name': '22_asteromphalus_hyalinus_jpg.rf.576476cc9b414323f14e025a60da302a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 89,
#   'license': 1,
#   'file_name': '23_asteromphalus_hyalinus_jpg.rf.501757358ab9d532a721ed51915bb4e7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 90,
#   'license': 1,
#   'file_name': '24_asteromphalus_hyalinus_jpg.rf.5bffdb67d71196e3bd254fee57c89020.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 91,
#   'license': 1,
#   'file_name': '04_asteromphalus_hyalinus_jpg.rf.28fe07e46903906ddbb9b7299bdd846c.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 92,
#   'license': 1,
#   'file_name': '16_dinophysis_caudata_jpg.rf.5d3f9f3ab6f1b95382d1319ace0613ea.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 93,
#   'license': 1,
#   'file_name': '04_pseudo_nitzschia_JPG.rf.5981f00ed722edced9068048c26b88fe.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 94,
#   'license': 1,
#   'file_name': '01_ornithocercus_thumii_jpg.rf.53e8fcb0da4cc9a5e61f48ff71398afc.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 95,
#   'license': 1,
#   'file_name': '04_odontella_mobiliensis_jpg.rf.6caef024bef9c6573d3f81e29197a7fd.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 96,
#   'license': 1,
#   'file_name': '19_proboscia_alata_jpg.rf.539f95e67ebb36e8a5b14510d3490d9b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 97,
#   'license': 1,
#   'file_name': '04_ceratium_furca_jpg.rf.62e0703f21861b9b20e0bfd9c8db6ee1.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 98,
#   'license': 1,
#   'file_name': '10_asteromphalus_hyalinus_jpg.rf.6b9648cbe4eb08299e9b851583b1dec5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 99,
#   'license': 1,
#   'file_name': '10_eucampia_zodiacus_jpg.rf.59c0be84ef038e18220e2a79663fa249.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 100,
#   'license': 1,
#   'file_name': '02_eucampia_zodiacus_jpg.rf.63dcea9ccac9ac57e13cd7f485a7dea5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 101,
#   'license': 1,
#   'file_name': '12_odontella_mobiliensis_jpg.rf.679e3d5f5cbba27aa6d26d459744d641.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 102,
#   'license': 1,
#   'file_name': '06_ornithocercus_thumii_jpg.rf.68463b458c1897af4b9a892d6c591b81.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 103,
#   'license': 1,
#   'file_name': '29_thalassionema_nitzschioides_jpg.rf.74b17436136c8073b456ad6f21bcac97.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 104,
#   'license': 1,
#   'file_name': '13_eucampia_zodiacus_jpg.rf.5e5101b6f7c8d922118e72859830b167.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 105,
#   'license': 1,
#   'file_name': '05_asteromphalus_hyalinus_jpg.rf.74a1d06f1cd08572942afc0e303fe7ae.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 106,
#   'license': 1,
#   'file_name': '07_asteromphalus_hyalinus_jpg.rf.4b789a903a915544aaf20203ce28a343.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 107,
#   'license': 1,
#   'file_name': '11_dinophysis_miles_jpg.rf.6a9ec3fd38f64d0c85d5bafe88140478.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 108,
#   'license': 1,
#   'file_name': '02_proboscia_alata_jpg.rf.65e301de863e6ba88ae04249a2dacdc3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 109,
#   'license': 1,
#   'file_name': '15_eucampia_zodiacus_jpg.rf.7105041e5154ae605b8d7cebb65ae0ab.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 110,
#   'license': 1,
#   'file_name': '08_eucampia_zodiacus_jpg.rf.73bacd870206ed0c44f9907104158e37.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 111,
#   'license': 1,
#   'file_name': '03_odontella_mobiliensis_jpg.rf.753d6007fa203eb4e9dc1c65be02b7be.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 112,
#   'license': 1,
#   'file_name': '06_prorocentrum_micans_jpg.rf.6e2e0a00c462bd6e5a61a2911a96a68c.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 113,
#   'license': 1,
#   'file_name': '15_pseudo_nitzschia_JPG.rf.788a2e3899e3027b736f0a4e05352285.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 114,
#   'license': 1,
#   'file_name': '05_protoperidinium_oceanicum_jpg.rf.68f31e2b9407c1cf78b0909cc247e686.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 115,
#   'license': 1,
#   'file_name': '01_ceratium_furca_jpg.rf.769c47dda99e92bc27fd660890fa837b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 116,
#   'license': 1,
#   'file_name': '10_proboscia_alata_jpg.rf.726b1515ef4102147eeda6d1366169e0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 117,
#   'license': 1,
#   'file_name': '14_skeletonema_costatum_jpg.rf.79d3aa54e99b3bedd65466170c431338.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 118,
#   'license': 1,
#   'file_name': '03_eucampia_zodiacus_jpg.rf.6d315e16c699a5636cbdaa684207ee3a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 119,
#   'license': 1,
#   'file_name': '12_proboscia_alata_jpg.rf.7ac5da432759ec7b4274dc064e513587.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 120,
#   'license': 1,
#   'file_name': '07_protoperidinium_oceanicum_jpg.rf.7f51b3567cc3a5d30ab6b85f2be1d2c1.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 121,
#   'license': 1,
#   'file_name': '08_thalassionema_nitzschioides_jpg.rf.5f1541e172556aebc74d7e60fa3788c5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 122,
#   'license': 1,
#   'file_name': '04_skeletonema_costatum_jpg.rf.7ed226751da9ffeab3346c98bda78e8e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 123,
#   'license': 1,
#   'file_name': '17_dinophysis_miles_jpg.rf.7af97eb334d93d42c7e69b4b0de3e877.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 124,
#   'license': 1,
#   'file_name': '17_protoperidinium_oceanicum_jpg.rf.623758e630914f0dfb488a4e4e0a9b06.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 125,
#   'license': 1,
#   'file_name': '12_skeletonema_costatum_jpg.rf.8198ddfbee74ab41385c13e8060e9725.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 126,
#   'license': 1,
#   'file_name': '08_podolampas_bipes_jpg.rf.84434c8ccb05d46351c5a9b928e35ac3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 127,
#   'license': 1,
#   'file_name': '22_ornithocercus_thumii_jpg.rf.83f14d8986ed7122fe5dfe4c2ca6bc1c.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 128,
#   'license': 1,
#   'file_name': '08_proboscia_alata_jpg.rf.8188d1e401531a0518d0655aaeaf72b0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 129,
#   'license': 1,
#   'file_name': '12_eucampia_zodiacus_jpg.rf.847ee64ff3eb7cb162b2af33cd7a897f.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 130,
#   'license': 1,
#   'file_name': '27_asteromphalus_hyalinus_jpg.rf.877eb2f39015109c171e81f62b2127a3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 131,
#   'license': 1,
#   'file_name': '15_dinophysis_caudata_jpg.rf.8b4f23eb42a01fb0ae71082a5bc01411.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 132,
#   'license': 1,
#   'file_name': '10_planktoniella_sol_jpg.rf.88aeafc307612361d276f1c6d00ab2f2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 133,
#   'license': 1,
#   'file_name': '08_dinophysis_caudata_jpg.rf.625a67e09201871b4c72909a10f6771a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 134,
#   'license': 1,
#   'file_name': '20_proboscia_alata_jpg.rf.8641e4bc80dae25b9cae061108c0db81.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 135,
#   'license': 1,
#   'file_name': '11_planktoniella_sol_jpg.rf.8d2087daf6717d8f46354e8d817fbe9d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 136,
#   'license': 1,
#   'file_name': '07_proboscia_alata_jpg.rf.8bc2e4f8f7a4263fcee83702b50918b0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 137,
#   'license': 1,
#   'file_name': '14_asteromphalus_hyalinus_jpg.rf.80563e4cd271a7739765eaab6d1ad4eb.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 138,
#   'license': 1,
#   'file_name': '21_ornithocercus_thumii_jpg.rf.91d2b50eab3b670791891472ac41bb97.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 139,
#   'license': 1,
#   'file_name': '05_podolampas_bipes_jpg.rf.867b683c6662ebec01fa9c01530b33fa.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 140,
#   'license': 1,
#   'file_name': '12_coscinodiscus_oculus_iridis_jpg.rf.87da0a68d5973793b88c6cf70d661268.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 141,
#   'license': 1,
#   'file_name': '14_coscinodiscus_oculus_iridis_jpg.rf.9a4e428484d77f752b44eb8b49ef936a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 142,
#   'license': 1,
#   'file_name': '04_ceratium_trichoceros_jpg.rf.9bdf1c5956168da2d3f6fb81fd2e80d8.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 143,
#   'license': 1,
#   'file_name': '28_coscinodiscus_oculus_iridis_jpg.rf.7def7580ee40bef50fcc979695c076af.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 144,
#   'license': 1,
#   'file_name': '05_noctilluca_scintillans_jpg.rf.870faa262e21e830f02ad62e4e0f141d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 145,
#   'license': 1,
#   'file_name': '09_dinophysis_miles_jpg.rf.7f8c77eadf61ca0f52c5f9ea87e1e1b4.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 146,
#   'license': 1,
#   'file_name': '22_coscinodiscus_oculus_iridis_jpg.rf.919c89d0b09d34f24c1e14c5b6edd64e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 147,
#   'license': 1,
#   'file_name': '07_podolampas_bipes_jpg.rf.9ca1198df45a1ebe5ec3d45eda758e19.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 148,
#   'license': 1,
#   'file_name': '07_coscinodiscus_oculus_iridis_jpg.rf.a1ad4cb263310a212911019dc9d447c2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 149,
#   'license': 1,
#   'file_name': '27_ornithocercus_thumii_jpg.rf.9e2d536abb8011aa4b1c2a1ab202d5ea.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 150,
#   'license': 1,
#   'file_name': '02_pseudo_nitzschia_jpg.rf.a752e9bd4effe63b926925fab6ef9eca.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 151,
#   'license': 1,
#   'file_name': '06_ceratium_trichoceros_jpg.rf.9ba57b15cb1ea1088483831af7dff6db.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 152,
#   'license': 1,
#   'file_name': '05_coscinodiscus_oculus_iridis_jpg.rf.865f930e2cf21b0abde6050d311516ed.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 153,
#   'license': 1,
#   'file_name': '06_asteromphalus_hyalinus_jpg.rf.a6fae000c8110c7143ac527d98ef6819.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 154,
#   'license': 1,
#   'file_name': '14_pseudo_nitzschia_JPG.rf.91a192f83d46a5c7e4ac4965b5b893aa.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 155,
#   'license': 1,
#   'file_name': '29_asteromphalus_hyalinus_jpg.rf.ad9562916e2c95d8662d9bc67b331ad0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 156,
#   'license': 1,
#   'file_name': '16_dinophysis_miles_jpg.rf.8a8464903a6ff492ba5eba8b89bce77a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 157,
#   'license': 1,
#   'file_name': '10_dinophysis_caudata_jpg.rf.aad08e6ca176d7fe58664a0a4a1e01cd.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 158,
#   'license': 1,
#   'file_name': '04_proboscia_alata_jpg.rf.a4a547d744c3914997a9fe1fce4ec752.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 159,
#   'license': 1,
#   'file_name': '28_asteromphalus_hyalinus_jpg.rf.9ddb9d2889cea69edc9d629a9038a1c6.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 160,
#   'license': 1,
#   'file_name': '03_skeletonema_costatum_jpg.rf.ad4c9b0352b750de7dbc64803c72767c.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 161,
#   'license': 1,
#   'file_name': '09_prorocentrum_micans_jpg.rf.b1db87135937220cafc3c071b6cea2ac.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 162,
#   'license': 1,
#   'file_name': '01_dinophysis_miles_jpg.rf.8f24dffa7387607e2d4482376cd40190.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 163,
#   'license': 1,
#   'file_name': '11_eucampia_zodiacus_jpg.rf.b18a42f3927fbd8eaa1bf9fe7bac2964.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 164,
#   'license': 1,
#   'file_name': '03_ceratium_trichoceros_jpg.rf.a6d5899a5d8d80d5b2fe549f5b8a8eaa.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 165,
#   'license': 1,
#   'file_name': '01_coscinodiscus_oculus_iridis_jpg.rf.ae57a14b797876e577588ebea2cf6773.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 166,
#   'license': 1,
#   'file_name': '16_ornithocercus_thumii_jpg.rf.abea6df9d9a24b0499ae5259dd0629c6.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 167,
#   'license': 1,
#   'file_name': '03_trichodesmium_erythraeum_jpg.rf.b6d39af6f0f5709b6c50cf6816b13b57.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 168,
#   'license': 1,
#   'file_name': '03_planktoniella_sol_jpg.rf.ba3b17f772f13848b29e72242157f146.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 169,
#   'license': 1,
#   'file_name': '07_ceratium_furca_jpg.rf.c1547a19b16bf18c1d55f24182b03697.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 170,
#   'license': 1,
#   'file_name': '33_asteromphalus_hyalinus_jpg.rf.c1dbd18264bab68e8440cbeef1930eae.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 171,
#   'license': 1,
#   'file_name': '14_planktoniella_sol_jpg.rf.be4964b91092f5109e4888c46a922791.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 172,
#   'license': 1,
#   'file_name': '04_noctilluca_scintillans_jpg.rf.bd602c20eac947daa0a4d27da5ee4ea3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 173,
#   'license': 1,
#   'file_name': '18_dinophysis_caudata_jpg.rf.b4e842cc6d3002b0841bb0d7a9062f69.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 174,
#   'license': 1,
#   'file_name': '23_coscinodiscus_oculus_iridis_jpg.rf.bc665d376d2c24ab322d28bc050764c4.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 175,
#   'license': 1,
#   'file_name': '02_prorocentrum_micans_jpg.rf.bd240a0a3c905af5ebce4313f02db3f7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 176,
#   'license': 1,
#   'file_name': '09_coscinodiscus_oculus_iridis_jpg.rf.b570acbb2e4c754d36df833d2a23e5bf.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 177,
#   'license': 1,
#   'file_name': '07_prorocentrum_micans_jpg.rf.c2e8a2d6a220dc0c9b7a51a274d33ad5.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 178,
#   'license': 1,
#   'file_name': '31_pseudo_nitzschia_JPG.rf.b23a479551717332d555297bdb296f56.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 179,
#   'license': 1,
#   'file_name': '06_dinophysis_miles_jpg.rf.c2c17b0d471538410fc28607be10fae0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 180,
#   'license': 1,
#   'file_name': '11_coscinodiscus_oculus_iridis_jpg.rf.bd39fdc0d1f2a732f44207da261ee4b9.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 181,
#   'license': 1,
#   'file_name': '05_dinophysis_miles_jpg.rf.d01ff73cd87d6cacb7c025b03869b025.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 182,
#   'license': 1,
#   'file_name': '07_dinophysis_miles_jpg.rf.bf7f3c53a5a14f8e41cd390dc90325ee.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 183,
#   'license': 1,
#   'file_name': '10_dinophysis_miles_jpg.rf.c58a40ab0e6e7c5aa820e405d7558f9d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 184,
#   'license': 1,
#   'file_name': '02_protoperidinium_oceanicum_jpg.rf.b955f134eff638d9c3a7e67facc3747b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 185,
#   'license': 1,
#   'file_name': '11_prorocentrum_micans_jpg.rf.ae3f36115f42c28a2c770c7d82cbc0e0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 186,
#   'license': 1,
#   'file_name': '09_eucampia_zodiacus_jpg.rf.c8e1f2191cdce6f60b35abdfd570c830.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 187,
#   'license': 1,
#   'file_name': '17_dinophysis_caudata_jpg.rf.c72571652d1feda4a944089899162f75.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 188,
#   'license': 1,
#   'file_name': '05_trichodesmium_erythraeum_jpg.rf.c3262d2f3b99fda69e37e96934dde1bc.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 189,
#   'license': 1,
#   'file_name': '25_ornithocercus_thumii_jpg.rf.d3d71f5a24391fe90d99c1a4b8ae03e7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 190,
#   'license': 1,
#   'file_name': '20_pseudo_nitzschia_JPG.rf.c1836406b6d926cc944f7b2108ab1fc6.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 191,
#   'license': 1,
#   'file_name': '05_ceratium_trichoceros_jpg.rf.d109f524d739eaed786cd307955cb08b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 192,
#   'license': 1,
#   'file_name': '04_eucampia_zodiacus_jpg.rf.d1638e96a254dcf9b76ee69ec8720ede.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 193,
#   'license': 1,
#   'file_name': '02_noctilluca_scintillans_jpg.rf.d649a884e3b9281497bc385154854a72.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 194,
#   'license': 1,
#   'file_name': '17_coscinodiscus_oculus_iridis_jpg.rf.d4aeebbb2b4aceab46a2f3a8ffa8479a.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 195,
#   'license': 1,
#   'file_name': '13_protoperidinium_oceanicum.rf.de740d890346997aa2567c971225cde7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 196,
#   'license': 1,
#   'file_name': '02_ornithocercus_thumii_jpg.rf.dadd5e9a81201b65a5e802e6c12acdaa.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 197,
#   'license': 1,
#   'file_name': '03_coscinodiscus_oculus_iridis_jpg.rf.c4e26b8fa53843091bbefa6872f1b6b7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 198,
#   'license': 1,
#   'file_name': '03_dinophysis_miles_jpg.rf.c6a94087eed2d1be2bdae3ff70fb3233.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 199,
#   'license': 1,
#   'file_name': '24_coscinodiscus_oculus_iridis_jpg.rf.d6ff9837a237bb2cf26340a55c13043f.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 200,
#   'license': 1,
#   'file_name': '06_proboscia_alata_jpg.rf.dd0d593551172eff89059d261c1418d7.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 201,
#   'license': 1,
#   'file_name': '12_podolampas_bipes_jpg.rf.d199efa882dfb3d54c268ced828b1216.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 202,
#   'license': 1,
#   'file_name': '01_protoperidinium_oceanicum_jpg.rf.dc3dc4fbc13d39d166be37fd54c5410d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 203,
#   'license': 1,
#   'file_name': '01_odontella_mobiliensis_jpg.rf.e5a1868b6723b7179a26960c554cd603.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 204,
#   'license': 1,
#   'file_name': '26_asteromphalus_hyalinus_jpg.rf.daad4a14aeb4513a08f36bc1d922bbdf.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 205,
#   'license': 1,
#   'file_name': '16_planktoniella_sol_jpg.rf.c85b6bd2c27f1e0cafc66edd809ddd4b.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 206,
#   'license': 1,
#   'file_name': '06_chaetoceros_curvisetus_jpg.rf.e41dcf5cee82825b49020aa134357cd1.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 207,
#   'license': 1,
#   'file_name': '16_coscinodiscus_oculus_iridis_jpg.rf.cd6c3fbd1844e56a69af0b360d1b7b0e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 208,
#   'license': 1,
#   'file_name': '09_ceratium_trichoceros_jpg.rf.e59d03664bb8dd3b3fa31ce51044f5f9.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 209,
#   'license': 1,
#   'file_name': '16_eucampia_zodiacus_jpg.rf.df43eb8fe2c76da6e8c7499b033955e3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 210,
#   'license': 1,
#   'file_name': '02_podolampas_bipes_jpg.rf.ea70888e5d43da2d0aaacde6c299a4c2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 211,
#   'license': 1,
#   'file_name': '23_pseudo_nitzschia_jpg.rf.dae79dbb8aaac34293be0201d8e2bd0e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 212,
#   'license': 1,
#   'file_name': '01_prorocentrum_micans_jpg.rf.dd313384d944c374f6d78d02e5ba78e3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 213,
#   'license': 1,
#   'file_name': '13_coscinodiscus_oculus_iridis_jpg.rf.e3b0b72c4e87504a4f5c5ab930f32fd2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 214,
#   'license': 1,
#   'file_name': '18_pseudo_nitzschia_JPG.rf.d8226600616380facf70ab5919c03fbb.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 215,
#   'license': 1,
#   'file_name': '10_ceratium_trichoceros_jpg.rf.ebb0875e0c0205844c1f569d22ef939e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 216,
#   'license': 1,
#   'file_name': '06_coscinodiscus_oculus_iridis_jpg.rf.e73878ba1cbb5c5bf7e404f9bc49ddcd.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 217,
#   'license': 1,
#   'file_name': '19_ornithocercus_thumii_jpg.rf.edd77e2e583882340bc81d0688b9ba6e.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 218,
#   'license': 1,
#   'file_name': '04_trichodesmium_erythraeum_jpg.rf.f4b762730ed85c00e40e886d78a274ab.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 219,
#   'license': 1,
#   'file_name': '20_coscinodiscus_oculus_iridis_jpg.rf.eb6184f3d143625c3ba38c533898e6f3.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 220,
#   'license': 1,
#   'file_name': '06_trichodesmium_erythraeum_jpg.rf.f1e54e891d16b066daa968576f1cdd1d.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 221,
#   'license': 1,
#   'file_name': '12_dinophysis_caudata_jpg.rf.ecc4efbcc3b78c1fcfd3dbf6cb55eefa.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 222,
#   'license': 1,
#   'file_name': '06_odontella_mobiliensis_jpg.rf.f83d69e52e723a2dd66e1055b8e393e0.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 223,
#   'license': 1,
#   'file_name': '02_dinophysis_miles_jpg.rf.f6f3dbf5573ecb88628b0b3241e4d0b2.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 224,
#   'license': 1,
#   'file_name': '35_thalassionema_nitzschioides_jpg.rf.ec2c1e272901c4fd451b9609afd2e4a8.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 225,
#   'license': 1,
#   'file_name': '15_planktoniella_sol_jpg.rf.ee1e0b1e01372138adafb6132c9c9a65.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'},
#  {'id': 226,
#   'license': 1,
#   'file_name': '19_pseudo_nitzschia_JPG.rf.f120cb495aa274f7500907495661de95.jpg',
#   'height': 512,
#   'width': 512,
#   'date_captured': '2023-05-16T09:40:09+00:00'}]

# %%
plot_plankton_by_id(train_dir, id_img=30)

# %%
plot_3_examples(train_dir)
